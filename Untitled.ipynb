# %%
# %matplotlib inline
import scattertext as st
import re, io
from pprint import pprint
import pandas as pd
import numpy as np
from scipy.stats import rankdata, hmean, norm
import spacy
import os, pkgutil, json, urllib
from urllib.request import urlopen
from IPython.display import IFrame
from IPython.core.display import display, HTML
from scattertext import CorpusFromPandas, produce_scattertext_explorer
display(HTML("&lt;style>.container { width:98% !important; }&lt;/style>"))
# Out:
# &lt;style>.container { width:98% !important; }&lt;/style>

# %%
import spacy
nlp = spacy.load('en')

# %%
convention_df = st.SampleCorpora.ConventionData2012.get_data()

# %%
convention_df.head()
# Out:
#       party         speaker                                               text
# 0  democrat    BARACK OBAMA  Thank you. Thank you. Thank you. Thank you so ...
# 1  democrat  MICHELLE OBAMA  Thank you so much. Tonight, I am so thrilled a...
# 2  democrat  RICHARD DURBIN  Thank you. It is a singular honor to be here t...
# 3  democrat    JOSEPH BIDEN  Hey, Delaware. \nAnd my favorite Democrat, Jil...
# 4  democrat      JILL BIDEN  Hello. \nThank you, Angie. I'm so proud of how...

# %%
convention_df['parsed'] = convention_df.text.apply(nlp)

# %%
print(convention_df.groupby('party')['text'].count())
convention_df.groupby('party').apply(lambda x: x.text.apply(lambda x: len(x.split())).sum())
# Out:
# party
# democrat      123
# republican     66
# Name: text, dtype: int64
# party
# democrat      76843
# republican    58144
# dtype: int64

# %%
corpus = st.CorpusFromParsedDocuments(convention_df, category_col='party', parsed_col='parsed').build()

# %%
html = produce_scattertext_explorer(corpus,
                                    category='democrat',
                                    category_name='Democratic',
                                    not_category_name='Republican',
                                    width_in_pixels=1000,
                                    minimum_term_frequency=5,
                                    transform=st.Scalers.scale,
                                    metadata=convention_df['speaker'])
file_name = 'output/Conventions2012ScattertextScale.html'
open(file_name, 'wb').write(html.encode('utf-8'))
IFrame(src=file_name, width = 1200, height=700)
# Out:
#         <iframe
#             width="1200"
#             height="700"
#             src="output/Conventions2012ScattertextScale.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
html = st.produce_scattertext_explorer(corpus,
                                       category='democrat',
                                       category_name='Democratic',
                                       not_category_name='Republican',
                                       minimum_term_frequency=5,
                                       width_in_pixels=1000,
                                       transform=st.Scalers.log_scale_standardize)
file_name = 'output/Conventions2012ScattertextLog.html'
open(file_name, 'wb').write(html.encode('utf-8'))
IFrame(src=file_name, width = 1000, height=700)
# Out:
#         <iframe
#             width="1000"
#             height="700"
#             src="output/Conventions2012ScattertextLog.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
html = produce_scattertext_explorer(corpus,
                                    category='democrat',
                                    category_name='Democratic',
                                    not_category_name='Republican',
                                    width_in_pixels=1000,
                                    minimum_term_frequency=5,
                                    transform=st.Scalers.log_scale_standardize,
                                    metadata=convention_df['speaker'])
file_name = 'output/Conventions2012ScattertextRankData.html'
open(file_name, 'wb').write(html.encode('utf-8'))
IFrame(src=file_name, width = 1000, height=700)
# Out:
#         <iframe
#             width="1000"
#             height="700"
#             src="output/Conventions2012ScattertextRankData.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
convention_df.head(200)
# Out:
#           party                   speaker  \
# 0      democrat              BARACK OBAMA
# 1      democrat            MICHELLE OBAMA
# 2      democrat            RICHARD DURBIN
# 3      democrat              JOSEPH BIDEN
# 4      democrat                JILL BIDEN
# 5      democrat              ANGIE FLORES
# 6      democrat              JOHN NATHMAN
# 7      democrat                JOHN KERRY
# 8      democrat             CHARLIE CRIST
# 9      democrat          BRIAN SCHWEITZER
# 10     democrat              EVA LONGORIA
# 11     democrat         JENNIFER GRANHOLM
# 12     democrat            XAVIER BECERRA
# 13     democrat          CAROLINE KENNEDY
# 14     democrat        SCARLETT JOHANSSON
# 15     democrat          KERRY WASHINGTON
# 16     democrat             JAMES CLYBURN
# 17     democrat                BEAU BIDEN
# 18     democrat            KENYETTA JONES
# 19     democrat               JIM MESSINA
# 20     democrat                ZACH WAHLS
# 21     democrat            MICHAEL NUTTER
# 22     democrat             TAMMY BALDWIN
# 23     democrat      ANTONIO VILLARAIGOSA
# 24     democrat  DEBBIE WASSERMAN SCHULTZ
# 25     democrat                JASON CROW
# 26     democrat         ALEJANDRA SALINAS
# 27     democrat                JOHN LEWIS
# 28     democrat              BARNEY FRANK
# 29     democrat              HARVEY GANTT
# ..          ...                       ...
# 159  republican         LUCE VELA FORTUNO
# 160  republican               NIKKI HALEY
# 161  republican               ARTUR DAVIS
# 162  republican                  TED CRUZ
# 163  republican             RICK SANTORUM
# 164  republican            BRIAN SANDOVAL
# 165  republican              SCOTT WALKER
# 166  republican             BOB MCDONNELL
# 167  republican               MARY FALLIN
# 168  republican               JOHN KASICH
# 169  republican              KELLY AYOTTE
# 170  republican    CATHY MCMORRIS RODGERS
# 171  republican           SHER VALENZUELA
# 172  republican             JANINE TURNER
# 173  republican            REINCE PRIEBUS
# 174  republican              JOHN BOEHNER
# 175  republican                STEVE KING
# 176  republican               RON KAUFMAN
# 177  republican               JOHN SUNUNU
# 178  republican          BARBARA COMSTOCK
# 179  republican          BARBARA COMSTOCK
# 180  republican              LISA STICKAN
# 181  republican       RAE LYNNE CHORNENKY
# 182  republican              MICK CORNETT
# 183  republican             CHRIS FUSSNER
# 184  republican             ALEX SCHRIVER
# 185  republican             PETE SESSIONS
# 186  republican              BOB BUCKHORN
# 187  republican                SHARON DAY
# 188  republican                  MIA LOVE
#
#                                                   text  \
# 0    Thank you. Thank you. Thank you. Thank you so ...
# 1    Thank you so much. Tonight, I am so thrilled a...
# 2    Thank you. It is a singular honor to be here t...
# 3    Hey, Delaware. \nAnd my favorite Democrat, Jil...
# 4    Hello. \nThank you, Angie. I'm so proud of how...
# 5    My name is Angie Flores and I am a student at ...
# 6    Today and every day, our military men and wome...
# 7    Thank you. Thank you.\nIn this — in this campa...
# 8    Good evening. \nHalf a century ago, Ronald Rea...
# 9    Settle down. Settle down.\nI know Mitt Romney....
# 10   Hello, Charlotte! I've got to tell you, I have...
# 11   Good evening. I'm Jennifer Granholm from the g...
# 12   You all having a good time? \nThat's Barack an...
# 13   It's an honor to join you tonight for the most...
# 14   Thank you. Thank you. It is an honor, an honor...
# 15   I am so grateful to be here with you tonight. ...
# 16   Thank you. Thank you. Good evening, and hello,...
# 17   My dad is Joe Biden. A few years ago he wrote ...
# 18   Good evening. I'm Kenyetta Jones from Toledo, ...
# 19   I'm so proud to represent the millions of volu...
# 20   Thank you, Charlotte. \nNow, people always wan...
# 21   I'm honored to serve as mayor of my hometown, ...
# 22   On behalf of the great state of Wisconsin and ...
# 23   Good evening. To the California delegation, I ...
# 24   Thank you. Thank you so much. I'm — thank you....
# 25   Thank you. I'm not a delegate, and I'm not a p...
# 26   Buenas noches, democratas. — and on my way to ...
# 27   Hello, Georgia. Hello, America.\nI first came ...
# 28   How are you? Hello.\nNice of them to leave a g...
# 29   Good evening, fellow Democrats.Since we were t...
# ..                                                 ...
# 159  Good evening, Tampa. My name is Luce, and it i...
# 160  I love South Carolina. \nI am the proud daught...
# 161  Thank you. Ladies and gentlemen, thank you. La...
# 162  Good evening.\nI have the honor of standing be...
# 163  Thank you. Thank you. Thank you. Thank you. Th...
# 164  Thank you. Thank you.\nI stand here tonight hu...
# 165  Thank you. \nOn June 5th, voters in Wisconsin ...
# 166  Thank you. Thank you very much. Good evening, ...
# 167  — there. Thank you.\nPresident Reagan once sai...
# 168  Thank you. Thank you. You know — \nAnd let me ...
# 169  "Live Free or Die." That's the motto of the gr...
# 170  Good evening, ladies and gentlemen. I'm Cathy ...
# 171  Good evening. My name is Sher Valenzuela. Two ...
# 172  Wow! Look at our republic at work! Whoo!\nHell...
# 173  Ladies and gentlemen, welcome back to the 2012...
# 174  Delegates, alternates, ladies and gentlemen, t...
# 175  Good evening. In two short months our country ...
# 176  A friend of mine who founded Staples with Mitt...
# 177  Good evening.\nIn these critical times, Americ...
# 178  Throughout his life, friends, family, business...
# 179  Greetings from the Commonwealth of Virginia, w...
# 180  \nAnd times are bad under Barack Obama and his...
# 181  Thank you. I bring you greetings from the Nati...
# 182  Well, this is quite a place. I'm just taking a...
# 183  Thank you. I am honored to be here today with ...
# 184  As the elected leader of 250,000 College Repub...
# 185  Good afternoon. I'm Pete Sessions, a congressm...
# 186  To Chairman Priebus and to my fellow Americans...
# 187  \nAbsolutely. Thank you, Mr.Chairman.\nWelcome...
# 188  I am thrilled to add Utah's voice in support f...
#
#                                                 parsed
# 0    (Thank, you, ., Thank, you, ., Thank, you, ., ...
# 1    (Thank, you, so, much, ., Tonight, ,, I, am, s...
# 2    (Thank, you, ., It, is, a, singular, honor, to...
# 3    (Hey, ,, Delaware, ., \n, And, my, favorite, D...
# 4    (Hello, ., \n, Thank, you, ,, Angie, ., I, 'm,...
# 5    (My, name, is, Angie, Flores, and, I, am, a, s...
# 6    (Today, and, every, day, ,, our, military, men...
# 7    (Thank, you, ., Thank, you, ., \n, In, this, —...
# 8    (Good, evening, ., \n, Half, a, century, ago, ...
# 9    (Settle, down, ., Settle, down, ., \n, I, know...
# 10   (Hello, ,, Charlotte, !, I, 've, got, to, tell...
# 11   (Good, evening, ., I, 'm, Jennifer, Granholm, ...
# 12   (You, all, having, a, good, time, ?, \n, That,...
# 13   (It, 's, an, honor, to, join, you, tonight, fo...
# 14   (Thank, you, ., Thank, you, ., It, is, an, hon...
# 15   (I, am, so, grateful, to, be, here, with, you,...
# 16   (Thank, you, ., Thank, you, ., Good, evening, ...
# 17   (My, dad, is, Joe, Biden, ., A, few, years, ag...
# 18   (Good, evening, ., I, 'm, Kenyetta, Jones, fro...
# 19   (I, 'm, so, proud, to, represent, the, million...
# 20   (Thank, you, ,, Charlotte, ., \n, Now, ,, peop...
# 21   (I, 'm, honored, to, serve, as, mayor, of, my,...
# 22   (On, behalf, of, the, great, state, of, Wiscon...
# 23   (Good, evening, ., To, the, California, delega...
# 24   (Thank, you, ., Thank, you, so, much, ., I, 'm...
# 25   (Thank, you, ., I, 'm, not, a, delegate, ,, an...
# 26   (Buenas, noches, ,, democratas, ., —, and, on,...
# 27   (Hello, ,, Georgia, ., Hello, ,, America, ., \...
# 28   (How, are, you, ?, Hello, ., \n, Nice, of, the...
# 29   (Good, evening, ,, fellow, Democrats, ., Since...
# ..                                                 ...
# 159  (Good, evening, ,, Tampa, ., My, name, is, Luc...
# 160  (I, love, South, Carolina, ., \n, I, am, the, ...
# 161  (Thank, you, ., Ladies, and, gentlemen, ,, tha...
# 162  (Good, evening, ., \n, I, have, the, honor, of...
# 163  (Thank, you, ., Thank, you, ., Thank, you, ., ...
# 164  (Thank, you, ., Thank, you, ., \n, I, stand, h...
# 165  (Thank, you, ., \n, On, June, 5th, ,, voters, ...
# 166  (Thank, you, ., Thank, you, very, much, ., Goo...
# 167  (—,  , there, ., Thank, you, ., \n, President,...
# 168  (Thank, you, ., Thank, you, ., You, know, —,  ...
# 169  (", Live, Free, or, Die, ., ", That, 's, the, ...
# 170  (Good, evening, ,, ladies, and, gentlemen, ., ...
# 171  (Good, evening, ., My, name, is, Sher, Valenzu...
# 172  (Wow, !, Look, at, our, republic, at, work, !,...
# 173  (Ladies, and, gentlemen, ,, welcome, back, to,...
# 174  (Delegates, ,, alternates, ,, ladies, and, gen...
# 175  (Good, evening, ., In, two, short, months, our...
# 176  (A, friend, of, mine, who, founded, Staples, w...
# 177  (Good, evening, ., \n, In, these, critical, ti...
# 178  (Throughout, his, life, ,, friends, ,, family,...
# 179  (Greetings, from, the, Commonwealth, of, Virgi...
# 180  (\n, And, times, are, bad, under, Barack, Obam...
# 181  (Thank, you, ., I, bring, you, greetings, from...
# 182  (Well, ,, this, is, quite, a, place, ., I, 'm,...
# 183  (Thank, you, ., I, am, honored, to, be, here, ...
# 184  (As, the, elected, leader, of, 250,000, Colleg...
# 185  (Good, afternoon, ., I, 'm, Pete, Sessions, ,,...
# 186  (To, Chairman, Priebus, and, to, my, fellow, A...
# 187  (\n, Absolutely, ., Thank, you, ,, Mr, ., Chai...
# 188  (I, am, thrilled, to, add, Utah, 's, voice, in...
#
# [189 rows x 4 columns]
