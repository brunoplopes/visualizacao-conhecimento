# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('dataset/multiTimeline.csv')

# %%
df
# Out:
#      year  variableA  variableB  variableC  variableD
# 0    2004         26          2         78          0
# 1    2004         36          2         91          0
# 2    2004         35          1        100          0
# 3    2004         32          2        100          0
# 4    2004         35          2         94          0
# 5    2004         31          2         76          0
# 6    2004         20          2         68          0
# 7    2004         31          2         87          0
# 8    2004         40          2         85          0
# 9    2004         32          1         79          0
# 10   2004         29          2         75          0
# 11   2004         18          2         67          0
# 12   2005         19          2         62          0
# 13   2005         26          2         63          0
# 14   2005         23          2         69          0
# 15   2005         29          1         72          0
# ...

# %%
df = df.groupby(['year']).sum()

# %%
df.to_csv('dataset/year_multi_timeline.csv')
